# %% [markdown]
# # Creation of a binary classifier with moons dataset
#
# ## Data creation and data split
# Make a binary classification dataset with Scikit-Learn's make_moons() function. For consistency, the dataset should have 1000 samples and a random_state=42.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
import torch
# Helper function to plot the moons dataset
def plot_moons(X, y):        
    # Create a scatter plot
    plt.figure(figsize=(8, 6))
    plt.scatter(X[y == 0, 0], X[y == 0, 1], color='red', label='Class 0')
    plt.scatter(X[y == 1, 0], X[y == 1, 1], color='blue', label='Class 1')
    
    # Add labels and title
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('Moon-shaped Binary Classification Dataset')
    plt.legend()
    plt.grid(True)
    
    # Show the plot
    plt.show()


X, y = make_moons(
    n_samples=1000, 
    noise=0.1,
    random_state=42
)

print(X.shape, y.shape)
print(type(X), type(y))

# Call the function with your data
plot_moons(X, y)
# Out:
# (1000, 2) (1000,)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %% [markdown]
# Turn the data into PyTorch tensors. Split the data into training and test sets using train_test_split with 80% training and 20% testing.

# %%
X = (
    torch.from_numpy(X) # We can use torch.from_numpy() to convert a numpy array to a torch tensor
    .type(torch.float) # We need to convert the data type to float to be compatible with PyTorch    
)

y = torch.from_numpy(y).type(torch.float)

# %%
# let's examing the shapes of the tensors
print(f"X.shape: {X.shape}, y.shape: {y.shape}")
# Notice that the y tensor contains values 0 and 1 representing each of the two classes
y[:10]
# Out:
# X.shape: torch.Size([1000, 2]), y.shape: torch.Size([1000])
# tensor([1., 1., 1., 1., 0., 1., 1., 1., 1., 0.])

# %%
# Lets split the data into training and test sets
train_split = int(0.8 * len(X))
X_train, X_test, y_train, y_test = X[:train_split], X[train_split:], y[:train_split], y[train_split:]

print(f"X_train.shape: {X_train.shape}, y_train.shape: {y_train.shape}")
print(f"X_test.shape: {X_test.shape}, y_test.shape: {y_test.shape}")
# Out:
# X_train.shape: torch.Size([800, 2]), y_train.shape: torch.Size([800])
# X_test.shape: torch.Size([200, 2]), y_test.shape: torch.Size([200])

# %% [markdown]
# # Make Device Agnostic

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %% [markdown]
# ## Building the model
# Build a model by subclassing nn.Module that incorporates non-linear activation functions and is capable of fitting the data you created in 1.

# %%
from torch import nn

class MoonModelV0(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=2, out_features=10)
        self.layer_2 = nn.Linear(in_features=10, out_features=10)
        self.layer_3 = nn.Linear(in_features=10, out_features=1)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        # Notice how we intercalate the non-linear function with the linear layers
        return self.layer_3(
            self.relu(
                self.layer_2(
                    self.relu(
                        self.layer_1(x)
                    )
                )
            )
        )

# %% [markdown]
# # Logits intro probabilities
# Remember that the model will output a raw unnormalized scores beloging to the last layer of the neural net.

# %%
# Make some predictions with the untrained model
model_v0 = MoonModelV0()
y_preds = model_v0(X_test)
print(f"shape of predictions: {y_preds.shape}")
print(y_preds[:10])
# Out:
# shape of predictions: torch.Size([200, 1])
# tensor([[ 0.0174],
#         [ 0.0265],
#         [ 0.0157],
#         [-0.0028],
#         [ 0.0227],
#         [ 0.0184],
#         [ 0.0314],
#         [ 0.0282],
#         [ 0.0162],
#         [ 0.0281]], grad_fn=<SliceBackward0>)

# %% [markdown]
#  We need to convert them to probabilities. In our case, we will use the sigmoid function so we can get a value between 0 and 1.

# %%
y_probabilities = torch.sigmoid(y_preds)
print(f"shape of probabilities: {y_probabilities.shape}")    
print(y_probabilities[:10])
print(f"min: {y_probabilities.min()}, max: {y_probabilities.max()}")
# Out:
# shape of probabilities: torch.Size([200, 1])
# tensor([[0.5043],
#         [0.5066],
#         [0.5039],
#         [0.4993],
#         [0.5057],
#         [0.5046],
#         [0.5079],
#         [0.5070],
#         [0.5041],
#         [0.5070]], grad_fn=<SliceBackward0>)
# min: 0.4972536861896515, max: 0.5104178190231323

# %% [markdown]
# Lets create a visualization to help us get an idea of the model performance..
# This visualization is particularly useful because it shows:
# - The decision boundary (where probability = 0.5)
# - The model's confidence in different regions
# - How well the model separates the two classes

# %%
def plot_decision_boundary(X, y, model):
    # Create a new figure with specified size
    plt.figure(figsize=(10, 8))
    
    # Find the boundaries of our plot
    # We add 0.5 to each side to have some padding around the data points
    # `X[:, 0]` gets the first column of X, which contains the first feature
    # `X[:, 1]` gets the second column of X, which contains the second feature
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5  # Boundaries for first feature
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5  # Boundaries for second feature
    
    # Create a grid of points that covers our data space
    # torch.linspace creates 100 evenly spaced points between min and max
    # meshgrid creates a 2D grid from these points (100x100 grid)
    xx, yy = torch.meshgrid(torch.linspace(x_min, x_max, 100),
                           torch.linspace(y_min, y_max, 100))
    
    # Prepare the grid points for model prediction:
    # 1. Flatten the grids and stack them to create pairs of (x,y) coordinates
    # 2. Shape becomes (10000, 2) where each row is a point to predict
    grid = torch.stack([xx.flatten(), yy.flatten()], dim=1)
    
    # Make predictions for all points in our grid
    with torch.no_grad():  # We don't need gradients for prediction
        logits = model(grid)  # Get raw model outputs
        probabilities = torch.sigmoid(logits)  # Convert to probabilities (0 to 1)
    
    # Reshape the predictions back to match our grid (100x100)
    probabilities = probabilities.reshape(xx.shape)
    
        # Print some example probabilities and their corresponding colors
    print("Example probability values and their colors:")
    print("0.0 -> Deep Red    (Very confident it's Class 0)")
    print("0.3 -> Light Red   (Somewhat confident it's Class 0)")
    print("0.5 -> White      (Decision boundary - Uncertain)")
    print("0.7 -> Light Blue  (Somewhat confident it's Class 1)")
    print("1.0 -> Deep Blue   (Very confident it's Class 1)")
    
    # Create the contour plot:
    # - xx and yy define the grid points
    # - probabilities defines the color at each point
    # - levels=20 creates 20 different color bands
    # - cmap='RdBu' uses a red-blue colormap (red for 0, blue for 1)
    plt.contourf(xx, yy, probabilities, levels=20, cmap='RdBu', alpha=0.7)
    
    # Add a colorbar to show the mapping between colors and probabilities
    plt.colorbar(label='Probability of Class 1')
    
    # Plot the original data points on top of the contour
    # Alpha makes the points slightly transparent
    plt.scatter(X[y == 0, 0], X[y == 0, 1], color='red', label='Class 0', alpha=0.7)
    plt.scatter(X[y == 1, 0], X[y == 1, 1], color='blue', label='Class 1', alpha=0.7)
    
    # Add labels and make the plot pretty
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('Decision Boundary with Probabilities')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the function with your model and data
plot_decision_boundary(X, y, model_v0)
# Out:
# Example probability values and their colors:
# 0.0 -> Deep Red    (Very confident it's Class 0)
# 0.3 -> Light Red   (Somewhat confident it's Class 0)
# 0.5 -> White      (Decision boundary - Uncertain)
# 0.7 -> Light Blue  (Somewhat confident it's Class 1)
# 1.0 -> Deep Blue   (Very confident it's Class 1)

# %% [markdown]
# ## Set loss, Optimizer, Accuracy functions
# Setup a binary classification compatible loss function and optimizer to use when training the model.

# %%
# This loss function has a sigmoid layer (nn.Sigmoid) built-in
# loss_fn = nn.BCEWithLogitsLoss()

loss_fn = nn.BCELoss()
optimizer = torch.optim.SGD(params=model_v0.parameters(), lr=0.1)

# Calculate accuracy (a classification metric)
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item() # torch.eq() calculates where two tensors are equal
    acc = (correct / len(y_pred)) * 100 
    return acc

# %% [markdown]
# # Build training loop

# %%
# Set the random state
torch.manual_seed(42)

# Lets put data into our device
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)
# Set number of epochs
epochs = 2000

for epoch in range(epochs):
    
    #===== TRAINING ======
    # Set the model in training mode
    model_v0.train()
    # 1. Forward step
    y_logits = model_v0(X_train).squeeze()
    y_pred = torch.round(torch.sigmoid(y_logits))
    
    # 2. Calculate loss and accuracy
    loss = loss_fn(
        torch.sigmoid(y_logits), # Using nn.BCELoss you need torch.sigmoid()
        y_train
    )    
    acc = accuracy_fn(y_train, y_pred)

    # 3. Set optimizer zero grad
    optimizer.zero_grad()
    
    # 4. Loss Backward
    loss.backward()

    # 5. Optimizer step
    optimizer.step()

    #===== TESTING =======
    # ----> Change the model to evaluation mode
    model_v0.eval()

    # ----> Perform the tests using the context manager to set torch in inference mode
    with torch.inference_mode():
        # 1.forward pass
        test_logits = model_v0(X_test).squeeze()
        test_pred = torch.round(torch.sigmoid(test_logits))
        # 2. Calculate the loss and accuracy
        test_loss = loss_fn(test_pred, y_test)
        test_acc = accuracy_fn(y_test, test_pred)
        # print out every 10 epochs
    if epoch % 10 == 0:
        print(f"Epoch: {epoch} | Loss: {loss:.5f}, Accuracy: {acc:.2f}% | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%")
# Out:
# Epoch: 0 | Loss: 0.69528, Accuracy: 39.12% | Test loss: 53.00000, Test acc: 47.00%
# Epoch: 10 | Loss: 0.68189, Accuracy: 72.88% | Test loss: 24.50000, Test acc: 75.50%
# Epoch: 20 | Loss: 0.66771, Accuracy: 79.12% | Test loss: 21.50000, Test acc: 78.50%
# Epoch: 30 | Loss: 0.65063, Accuracy: 78.00% | Test loss: 25.00000, Test acc: 75.00%
# Epoch: 40 | Loss: 0.62627, Accuracy: 74.88% | Test loss: 27.00000, Test acc: 73.00%
# Epoch: 50 | Loss: 0.59392, Accuracy: 74.62% | Test loss: 26.50000, Test acc: 73.50%
# Epoch: 60 | Loss: 0.55442, Accuracy: 75.38% | Test loss: 25.00000, Test acc: 75.00%
# Epoch: 70 | Loss: 0.50982, Accuracy: 76.12% | Test loss: 24.00000, Test acc: 76.00%
# Epoch: 80 | Loss: 0.46453, Accuracy: 77.75% | Test loss: 22.50000, Test acc: 77.50%
# Epoch: 90 | Loss: 0.42381, Accuracy: 78.88% | Test loss: 20.00000, Test acc: 80.00%
# Epoch: 100 | Loss: 0.38996, Accuracy: 80.62% | Test loss: 19.50000, Test acc: 80.50%
# Epoch: 110 | Loss: 0.36254, Accuracy: 83.25% | Test loss: 19.00000, Test acc: 81.00%
# Epoch: 120 | Loss: 0.34002, Accuracy: 84.25% | Test loss: 18.00000, Test acc: 82.00%
# Epoch: 130 | Loss: 0.32103, Accuracy: 85.12% | Test loss: 18.00000, Test acc: 82.00%
# Epoch: 140 | Loss: 0.30468, Accuracy: 85.50% | Test loss: 17.50000, Test acc: 82.50%
# Epoch: 150 | Loss: 0.29038, Accuracy: 87.00% | Test loss: 15.50000, Test acc: 84.50%
# Epoch: 160 | Loss: 0.27774, Accuracy: 87.38% | Test loss: 14.00000, Test acc: 86.00%
# Epoch: 170 | Loss: 0.26670, Accuracy: 87.75% | Test loss: 13.00000, Test acc: 87.00%
# Epoch: 180 | Loss: 0.25711, Accuracy: 88.12% | Test loss: 12.50000, Test acc: 87.50%
# Epoch: 190 | Loss: 0.24863, Accuracy: 88.25% | Test loss: 12.50000, Test acc: 87.50%
# Epoch: 200 | Loss: 0.24127, Accuracy: 88.50% | Test loss: 12.00000, Test acc: 88.00%
# Epoch: 210 | Loss: 0.23507, Accuracy: 89.00% | Test loss: 12.00000, Test acc: 88.00%
# Epoch: 220 | Loss: 0.22975, Accuracy: 89.25% | Test loss: 11.00000, Test acc: 89.00%
# Epoch: 230 | Loss: 0.22520, Accuracy: 89.25% | Test loss: 10.50000, Test acc: 89.50%
# Epoch: 240 | Loss: 0.22115, Accuracy: 89.62% | Test loss: 9.50000, Test acc: 90.50%
# Epoch: 250 | Loss: 0.21758, Accuracy: 90.25% | Test loss: 9.00000, Test acc: 91.00%
# Epoch: 260 | Loss: 0.21435, Accuracy: 90.25% | Test loss: 8.50000, Test acc: 91.50%
# Epoch: 270 | Loss: 0.21134, Accuracy: 90.12% | Test loss: 8.00000, Test acc: 92.00%
# Epoch: 280 | Loss: 0.20846, Accuracy: 90.62% | Test loss: 7.50000, Test acc: 92.50%
# Epoch: 290 | Loss: 0.20565, Accuracy: 90.62% | Test loss: 8.00000, Test acc: 92.00%
# Epoch: 300 | Loss: 0.20286, Accuracy: 90.62% | Test loss: 8.00000, Test acc: 92.00%
# Epoch: 310 | Loss: 0.20006, Accuracy: 91.00% | Test loss: 8.00000, Test acc: 92.00%
# Epoch: 320 | Loss: 0.19722, Accuracy: 90.88% | Test loss: 8.00000, Test acc: 92.00%
# Epoch: 330 | Loss: 0.19433, Accuracy: 91.00% | Test loss: 8.00000, Test acc: 92.00%
# Epoch: 340 | Loss: 0.19136, Accuracy: 91.12% | Test loss: 7.50000, Test acc: 92.50%
# Epoch: 350 | Loss: 0.18831, Accuracy: 91.38% | Test loss: 7.50000, Test acc: 92.50%
# Epoch: 360 | Loss: 0.18516, Accuracy: 91.62% | Test loss: 7.50000, Test acc: 92.50%
# Epoch: 370 | Loss: 0.18194, Accuracy: 91.75% | Test loss: 7.50000, Test acc: 92.50%
# Epoch: 380 | Loss: 0.17863, Accuracy: 92.25% | Test loss: 7.00000, Test acc: 93.00%
# Epoch: 390 | Loss: 0.17523, Accuracy: 92.25% | Test loss: 7.00000, Test acc: 93.00%
# Epoch: 400 | Loss: 0.17175, Accuracy: 92.38% | Test loss: 7.00000, Test acc: 93.00%
# Epoch: 410 | Loss: 0.16817, Accuracy: 92.38% | Test loss: 7.00000, Test acc: 93.00%
# Epoch: 420 | Loss: 0.16450, Accuracy: 92.75% | Test loss: 7.00000, Test acc: 93.00%
# Epoch: 430 | Loss: 0.16077, Accuracy: 92.75% | Test loss: 6.50000, Test acc: 93.50%
# Epoch: 440 | Loss: 0.15698, Accuracy: 92.75% | Test loss: 6.50000, Test acc: 93.50%
# Epoch: 450 | Loss: 0.15313, Accuracy: 93.00% | Test loss: 6.50000, Test acc: 93.50%
# Epoch: 460 | Loss: 0.14922, Accuracy: 93.38% | Test loss: 6.50000, Test acc: 93.50%
# Epoch: 470 | Loss: 0.14529, Accuracy: 93.62% | Test loss: 6.50000, Test acc: 93.50%
# Epoch: 480 | Loss: 0.14134, Accuracy: 93.75% | Test loss: 6.00000, Test acc: 94.00%
# Epoch: 490 | Loss: 0.13740, Accuracy: 94.00% | Test loss: 6.00000, Test acc: 94.00%
# Epoch: 500 | Loss: 0.13346, Accuracy: 94.12% | Test loss: 5.50000, Test acc: 94.50%
# Epoch: 510 | Loss: 0.12954, Accuracy: 94.62% | Test loss: 5.50000, Test acc: 94.50%
# Epoch: 520 | Loss: 0.12564, Accuracy: 94.88% | Test loss: 4.00000, Test acc: 96.00%
# Epoch: 530 | Loss: 0.12177, Accuracy: 95.12% | Test loss: 4.00000, Test acc: 96.00%
# Epoch: 540 | Loss: 0.11795, Accuracy: 95.38% | Test loss: 4.00000, Test acc: 96.00%
# Epoch: 550 | Loss: 0.11420, Accuracy: 95.62% | Test loss: 4.00000, Test acc: 96.00%
# Epoch: 560 | Loss: 0.11053, Accuracy: 95.62% | Test loss: 4.00000, Test acc: 96.00%
# Epoch: 570 | Loss: 0.10694, Accuracy: 95.88% | Test loss: 4.00000, Test acc: 96.00%
# Epoch: 580 | Loss: 0.10343, Accuracy: 96.12% | Test loss: 4.00000, Test acc: 96.00%
# Epoch: 590 | Loss: 0.10000, Accuracy: 96.25% | Test loss: 3.50000, Test acc: 96.50%
# Epoch: 600 | Loss: 0.09668, Accuracy: 96.62% | Test loss: 3.50000, Test acc: 96.50%
# Epoch: 610 | Loss: 0.09345, Accuracy: 96.88% | Test loss: 3.50000, Test acc: 96.50%
# Epoch: 620 | Loss: 0.09032, Accuracy: 97.25% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 630 | Loss: 0.08728, Accuracy: 97.50% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 640 | Loss: 0.08434, Accuracy: 97.62% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 650 | Loss: 0.08150, Accuracy: 97.88% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 660 | Loss: 0.07877, Accuracy: 97.88% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 670 | Loss: 0.07615, Accuracy: 98.00% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 680 | Loss: 0.07362, Accuracy: 98.12% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 690 | Loss: 0.07120, Accuracy: 98.38% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 700 | Loss: 0.06888, Accuracy: 98.50% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 710 | Loss: 0.06666, Accuracy: 98.62% | Test loss: 3.00000, Test acc: 97.00%
# Epoch: 720 | Loss: 0.06454, Accuracy: 98.75% | Test loss: 2.50000, Test acc: 97.50%
# Epoch: 730 | Loss: 0.06252, Accuracy: 98.75% | Test loss: 2.50000, Test acc: 97.50%
# Epoch: 740 | Loss: 0.06059, Accuracy: 98.88% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 750 | Loss: 0.05873, Accuracy: 99.00% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 760 | Loss: 0.05696, Accuracy: 99.12% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 770 | Loss: 0.05527, Accuracy: 99.12% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 780 | Loss: 0.05365, Accuracy: 99.12% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 790 | Loss: 0.05210, Accuracy: 99.12% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 800 | Loss: 0.05062, Accuracy: 99.12% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 810 | Loss: 0.04921, Accuracy: 99.12% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 820 | Loss: 0.04787, Accuracy: 99.12% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 830 | Loss: 0.04658, Accuracy: 99.25% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 840 | Loss: 0.04535, Accuracy: 99.25% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 850 | Loss: 0.04417, Accuracy: 99.25% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 860 | Loss: 0.04304, Accuracy: 99.25% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 870 | Loss: 0.04196, Accuracy: 99.25% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 880 | Loss: 0.04092, Accuracy: 99.38% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 890 | Loss: 0.03993, Accuracy: 99.38% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 900 | Loss: 0.03898, Accuracy: 99.38% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 910 | Loss: 0.03807, Accuracy: 99.38% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 920 | Loss: 0.03720, Accuracy: 99.38% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 930 | Loss: 0.03636, Accuracy: 99.38% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 940 | Loss: 0.03556, Accuracy: 99.38% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 950 | Loss: 0.03478, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 960 | Loss: 0.03404, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 970 | Loss: 0.03332, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 980 | Loss: 0.03263, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 990 | Loss: 0.03196, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1000 | Loss: 0.03133, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1010 | Loss: 0.03071, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1020 | Loss: 0.03011, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1030 | Loss: 0.02954, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1040 | Loss: 0.02899, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1050 | Loss: 0.02845, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1060 | Loss: 0.02794, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1070 | Loss: 0.02745, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1080 | Loss: 0.02697, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1090 | Loss: 0.02650, Accuracy: 99.50% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1100 | Loss: 0.02605, Accuracy: 99.62% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1110 | Loss: 0.02562, Accuracy: 99.62% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1120 | Loss: 0.02520, Accuracy: 99.62% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1130 | Loss: 0.02480, Accuracy: 99.62% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1140 | Loss: 0.02440, Accuracy: 99.62% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1150 | Loss: 0.02402, Accuracy: 99.62% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1160 | Loss: 0.02366, Accuracy: 99.62% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1170 | Loss: 0.02330, Accuracy: 99.62% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1180 | Loss: 0.02295, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1190 | Loss: 0.02261, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1200 | Loss: 0.02229, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1210 | Loss: 0.02197, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1220 | Loss: 0.02166, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1230 | Loss: 0.02136, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1240 | Loss: 0.02107, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1250 | Loss: 0.02079, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1260 | Loss: 0.02051, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1270 | Loss: 0.02024, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1280 | Loss: 0.01998, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1290 | Loss: 0.01973, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1300 | Loss: 0.01948, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1310 | Loss: 0.01924, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1320 | Loss: 0.01901, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1330 | Loss: 0.01878, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1340 | Loss: 0.01856, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1350 | Loss: 0.01835, Accuracy: 99.75% | Test loss: 2.00000, Test acc: 98.00%
# Epoch: 1360 | Loss: 0.01814, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1370 | Loss: 0.01793, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1380 | Loss: 0.01774, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1390 | Loss: 0.01754, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1400 | Loss: 0.01735, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1410 | Loss: 0.01717, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1420 | Loss: 0.01698, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1430 | Loss: 0.01681, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1440 | Loss: 0.01664, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1450 | Loss: 0.01647, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1460 | Loss: 0.01630, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1470 | Loss: 0.01614, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1480 | Loss: 0.01599, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1490 | Loss: 0.01583, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1500 | Loss: 0.01568, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1510 | Loss: 0.01553, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1520 | Loss: 0.01539, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1530 | Loss: 0.01525, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1540 | Loss: 0.01511, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1550 | Loss: 0.01497, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1560 | Loss: 0.01484, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1570 | Loss: 0.01471, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1580 | Loss: 0.01459, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1590 | Loss: 0.01446, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1600 | Loss: 0.01434, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1610 | Loss: 0.01422, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1620 | Loss: 0.01410, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1630 | Loss: 0.01399, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1640 | Loss: 0.01387, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1650 | Loss: 0.01376, Accuracy: 99.75% | Test loss: 1.50000, Test acc: 98.50%
# Epoch: 1660 | Loss: 0.01366, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1670 | Loss: 0.01355, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1680 | Loss: 0.01345, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1690 | Loss: 0.01334, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1700 | Loss: 0.01324, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1710 | Loss: 0.01314, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1720 | Loss: 0.01305, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1730 | Loss: 0.01295, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1740 | Loss: 0.01286, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1750 | Loss: 0.01277, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1760 | Loss: 0.01268, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1770 | Loss: 0.01259, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1780 | Loss: 0.01250, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1790 | Loss: 0.01242, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1800 | Loss: 0.01233, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1810 | Loss: 0.01225, Accuracy: 99.75% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1820 | Loss: 0.01217, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1830 | Loss: 0.01209, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1840 | Loss: 0.01201, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1850 | Loss: 0.01193, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1860 | Loss: 0.01185, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1870 | Loss: 0.01178, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1880 | Loss: 0.01170, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1890 | Loss: 0.01163, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1900 | Loss: 0.01156, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1910 | Loss: 0.01149, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1920 | Loss: 0.01142, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1930 | Loss: 0.01135, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1940 | Loss: 0.01128, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1950 | Loss: 0.01122, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1960 | Loss: 0.01115, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1970 | Loss: 0.01109, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1980 | Loss: 0.01102, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%
# Epoch: 1990 | Loss: 0.01096, Accuracy: 99.88% | Test loss: 1.00000, Test acc: 99.00%

# %%
# Call the function with your model and data
plot_decision_boundary(X, y, model_v0)
# Out:
# Example probability values and their colors:
# 0.0 -> Deep Red    (Very confident it's Class 0)
# 0.3 -> Light Red   (Somewhat confident it's Class 0)
# 0.5 -> White      (Decision boundary - Uncertain)
# 0.7 -> Light Blue  (Somewhat confident it's Class 1)
# 1.0 -> Deep Blue   (Very confident it's Class 1)
